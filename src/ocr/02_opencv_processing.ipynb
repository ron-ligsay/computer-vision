# %% [markdown]
# ##### Processing Images for OCR
# 1. Inverted Images
# 2. Rescaling
# 3. Binarization
# 4. Noise Removal
# 5. Dilation and Erosion
# 5. Contour Detection
# 6. Rotation/Deskewing
# 7. Removing Borders
# 8. Missing Borders
# 9. Transparancy/Alpha Channels

# %% [markdown]
# ##### Setup

# %%
import cv2

import matplotlib.pyplot as plt

# %% [markdown]
# ##### 00. Opening an Image

# %%
PATH = "C:/Users/aky/Documents/Programs/computer-vision/"
PATH2 = "C:\\Users\\aky\\Documents\\Programs\\computer-vision\\"
PATH3 = r"C:\Users\aky\Documents\Programs\computer-vision"
TEMP = "C:/Users/aky/Documents/Programs/computer-vision/data/temp/"
image_file = PATH + 'data/pdf/page_01.jpg'
img = cv2.imread(image_file)

# %%
# Display image on screen with OpenCV
# cv2.imshow('Original Image', img)
# cv2.waitKey(0)
# Out:
# -1

# %%
def display(im_path):
    dpi = 80
    im_data = plt.imread(im_path)
    height, width, depth = im_data.shape
    
    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(im_data, cmap='gray')
    
    plt.show()

# %%
display(image_file)

# %% [markdown]
# ##### 01: Inverted Images

# %%
inverted_image = cv2.bitwise_not(img)
cv2.imwrite(r'' + PATH3 + '\data\temp\inverted_image.jpg', inverted_image)
# Out:
# False

# %%
display(PATH + 'data/temp/inverted_image.jpg')

# %% [markdown]
# ##### 02: Rescalling

# %% [markdown]
# ##### 03: Binarization

# %%
def grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
gray_image = grayscale(img)
cv2.imwrite(TEMP + "gray.jpg", gray_image)
# Out:
# False

# %%
display("temp/gray.jpg")

# %%
thresh, im_bw = cv2.threshold(gray_image, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
cv2.imwrite(TEMP + "im_bw.jpg", im_bw)
# Out:
# False

# %%
display("temp/im_bw.jpg")

# %% [markdown]
# ##### 04: Noise Removal

# %% [markdown]
# ##### 05: Dilation and Erosion

# %% [markdown]
# ##### 06: Contour Detection

# %% [markdown]
# ##### 07: Rotation/Deskewing

# %% [markdown]
# ##### 08: Removing Borders

# %% [markdown]
# ##### 09: Missing Borders

# %% [markdown]
# ##### 10: Transparanc/Apha Channels

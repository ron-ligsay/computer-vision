# %% [markdown]
# # RGB vs Grayscale

# %%
# !pip install scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.20.0-cp38-cp38-win_amd64.whl (23.6 MB)
#      ---------------------------------------- 23.6/23.6 MB 9.8 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.4.1-cp38-cp38-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=9.0.1 in c:\users\aky\appdata\local\programs\python\python38\lib\site-packages (from scikit-image) (9.2.0)
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2023.3.21-py3-none-any.whl (218 kB)
#      -------------------------------------- 218.7/218.7 kB 6.7 MB/s eta 0:00:00
# Collecting networkx>=2.8
#   Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: scipy<1.9.2,>=1.8 in c:\users\aky\appdata\local\programs\python\python38\lib\site-packages (from scikit-image) (1.8.1)
# Collecting lazy_loader>=0.1
#   Downloading lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\aky\appdata\local\programs\python\python38\lib\site-packages (from scikit-image) (21.3)
# Requirement already satisfied: numpy>=1.21.1 in c:\users\aky\appdata\local\programs\python\python38\lib\site-packages (from scikit-image) (1.22.3)
# Collecting imageio>=2.4.1
#   Downloading imageio-2.27.0-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\aky\appdata\local\programs\python\python38\lib\site-packages (from packaging>=20.0->scikit-image) (3.0.9)
# Installing collected packages: tifffile, PyWavelets, networkx, lazy_loader, imageio, scikit-image
# Successfully installed PyWavelets-1.4.1 imageio-2.27.0 lazy_loader-0.2 networkx-3.0 scikit-image-0.20.0 tifffile-2023.3.21

# %%
from skimage import data
rocket_image = data.rocket()

# %% [markdown]
# ### Visualizing images in the course

# %%
# Import Visualization Library
import matplotlib.pyplot as plt

# %%
# Display the image
plt.imshow(rocket_image)
plt.show()

# %% [markdown]
# ###
